# %% [markdown]
# ## Import packages

# %%
import os, sys, warnings, random, glob, pylab, numpy as np, pandas as pd

# packages for visualization
import pydicom, cv2, seaborn as sns, matplotlib.pyplot as plt
from matplotlib import patches
from PIL import Image
# packages for model
import tensorflow as tf, keras
from keras.backend.tensorflow_backend import set_session
from keras.models import load_model
from sklearn.model_selection import KFold
from tqdm import tqdm
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 0 Setting

# %%
pd.set_option('display.max_columns',50)
warnings.filterwarnings("ignore")

# %%
# 1 Limit GPU usage
tf_config = tf.ConfigProto()
tf_config.gpu_options.per_process_gpu_memory_fraction = 0.8
set_session(tf.Session(config=tf_config))
#

# %% [markdown]
# tf_config = tf.ConfigProto()
# tf_config.gpu_options.allow_growth = True
# set_session(session = tf.Session(config=tf_config))

# %%
# Project Diretory
os.chdir('/home/ubuntu/healthcare/pneumonia_lungfish/')

# Source Directory
src = '/home/ubuntu/healthcare/pneumonia_lungfish/src'

#Data directory
raw_data_DIR = '/home/ubuntu/healthcare/pneumonia_lungfish/src/data/raw'
procesed_data_DIR = '/home/ubuntu/healthcare/pneumonia_lungfish/src/data/processed'
validation_result_DIR ='/home/ubuntu/healthcare/pneumonia_lungfish/src/data/validation_result'


#Image directory
train_dicom_DIR = '/home/ubuntu/healthcare/pneumonia_lungfish/src/data/raw/stage_2_train_images/'
# A list of images in the train_dicom_DIR
train_dicom = [f for f in os.listdir(train_dicom_DIR) if os.path.isfile(os.path.join(train_dicom_DIR, f))]

# Model Directory
MASK_RCNN = '/home/ubuntu/healthcare/pneumonia_lungfish/src/Mask_RCNN'
COCO_WEIGHTS_PATH = "/home/ubuntu/healthcare/pneumonia_lungfish/src/Mask_RCNN_coco_weights/mask_rcnn_coco.h5"
models_working_DIR = '/home/ubuntu/healthcare/pneumonia_lungfish/src/models_working'
models_save_DIR = '/home/ubuntu/healthcare/pneumonia_lungfish/src/models_save'

#Visulization diretory
visul_DIR = '/home/ubuntu/healthcare/pneumonia_lungfish/reports/figures'
feature_DIR = '/home/ubuntu/healthcare/pneumonia_lungfish/src/features/'


#to delete 

ktest_data_DIR = '/home/ubuntu/healthcare/pneumonia_lungfish/src/data/ktest'

# %% [markdown]
# ## I. EDA of Dataframes

# %% [markdown]
# #### 1) Prepare a dataframe df_path listing the path for each image

# %%
df_path = pd.DataFrame({'path': glob.glob(os.path.join(train_dicom_DIR, '*.dcm'))})
df_path['patientId'] = df_path['path'].map(lambda x: os.path.splitext(os.path.basename(x))[0])
print(df_path.head(2))
print(df_path.shape[0], 'images in total')
# Out:
#                                                 path  \
# 0  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 1  /home/ubuntu/healthcare/pneumonia_lungfish/src...
#
#                               patientId
# 0  79d6e398-6ee6-4c5a-b924-a082d3c1cce9
# 1  77a4deeb-5538-4c93-82e1-ef9c8877aaeb
# 26684 images in total

# %% [markdown]
# #### 2) Prepare a dataframe df_merge which contains both train_labels and train_infor

# %%
train_labels = pd.read_csv(os.path.join(raw_data_DIR,'stage_2_train_labels.csv'))
train_info = pd.read_csv(os.path.join(raw_data_DIR,'stage_2_detailed_class_info.csv'))
print(train_labels.head(2))
print(train_info.head(2))
# Out:
#                               patientId   x   y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6 NaN NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd NaN NaN    NaN     NaN       0
#                               patientId                         class
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6  No Lung Opacity / Not Normal
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd  No Lung Opacity / Not Normal

# %%
df_merge = pd.merge(train_labels,train_info, on='patientId',how='left')
print(df_merge.head())
# Out:
#                               patientId      x      y  width  height  Target  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
#
#                           class
# 0  No Lung Opacity / Not Normal
# 1  No Lung Opacity / Not Normal
# 2  No Lung Opacity / Not Normal
# 3                        Normal
# 4                  Lung Opacity

# %%
df_merge.to_csv(os.path.join(procesed_data_DIR,'df_train_labels_infor_merge.csv'), index = False)

# %% [markdown]
# ####  What are the data fields?
#
# The training data is provided as a set of patientIds and bounding boxes.
#   * x_ - the upper-left x coordinate of the bounding box.
#   * y_ - the upper-left y coordinate of the bounding box.
#   * width_ - the width of the bounding box.
#   * height_ - the height of the bounding box.
#
#
# patientId _- A patientId. Each patientId corresponds to a unique image.
# Target_ - the binary Target, indicating whether this sample has evidence of pneumonia.
#
# * For Target =1, pneumonia, there is x, y, width, and height
# * For Target = 0, non-pneumonia, these cells are blank

# %% [markdown]
# #### 3) Prepare a dataframe df_dropdup which has no replicated rows

# %%
print(df_merge.info())
df_dropdup = df_merge.drop_duplicates()
print(df_dropdup.info())

df_dropdup.to_csv(os.path.join(procesed_data_DIR, 'df_train_labels_infor_merge.csv'), index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37629 entries, 0 to 37628
# Data columns (total 7 columns):
# patientId    37629 non-null object
# x            16957 non-null float64
# y            16957 non-null float64
# width        16957 non-null float64
# height       16957 non-null float64
# Target       37629 non-null int64
# class        37629 non-null object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 2.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30227 entries, 0 to 37627
# Data columns (total 7 columns):
# patientId    30227 non-null object
# x            9555 non-null float64
# y            9555 non-null float64
# width        9555 non-null float64
# height       9555 non-null float64
# Target       30227 non-null int64
# class        30227 non-null object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 1.8+ MB
# None

# %% [markdown]
# #### Yes, There are 7402 replicates in the train_label or train_info csv files

# %%
df_dropdup.groupby(['class', 'Target']).size().reset_index(name=' Count')
# Out:
#                           class  Target   Count
# 0                  Lung Opacity       1    9555
# 1  No Lung Opacity / Not Normal       0   11821
# 2                        Normal       0    8851

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
# Count plot, x Target, color is target
sns.countplot(x = 'Target', hue = 'Target', data = df_dropdup,ax=axes[0])
sns.countplot(x = 'class', hue = 'Target', data = df_dropdup, ax=axes[1])
fig.savefig(os.path.join(visul_DIR,'Sample_target_class_count.png'), figdpi = 600)

# %% [markdown]
# #### 4) Prepare a dataframe df_box which includes bounding box information

# %% [markdown]
# ##### Are there more than one row for one patient?

# %%
#Group by patientId and count
print(df_dropdup['patientId'].value_counts().value_counts())

# check the head
print(df_dropdup['patientId'].value_counts().head(2))
# Out:
# 1    23286
# 2     3266
# 3      119
# 4       13
# Name: patientId, dtype: int64
# 1c44e0a4-4612-438f-9a83-8d5bf919cb67    4
# 0e03c2d7-9cea-4dc7-8e91-794a8b3ff58d    4
# Name: patientId, dtype: int64

# %% [markdown]
# ##### Yes. Why? For Patients with Target = 1, there is additional information for bounding boxes

# %%
box_counts = df_dropdup.groupby(['patientId','Target'])\
.size()\
.sort_values(ascending=False)\
.reset_index(name='boxes')
print(box_counts.head(2))
# Out:
#                               patientId  Target  boxes
# 0  7d674c82-5501-4730-92c5-d241fd6911e7       1      4
# 1  31764d54-ea3b-434f-bae2-8c579ed13799       1      4

# %%
df_box = pd.merge(df_dropdup, box_counts, on = ['patientId','Target'],how='left')
# Calculate the right and upper limit of boxes 
df_box['x_2'] = df_box['x'] + df_box['width']
df_box['y_2'] = df_box['y'] + df_box['height']
df_box['x_center'] = df_box['x'] + df_box['width'] / 2
df_box['y_center'] = df_box['y'] + df_box['height'] / 2
df_box['area'] = df_box['width'] * df_box['height']

print(df_box.head(2))
df_box.to_csv(os.path.join(procesed_data_DIR, 'df_train_labels_infor_boxes_merge.csv'), index = False)
# Out:
#                               patientId   x   y  width  height  Target  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6 NaN NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd NaN NaN    NaN     NaN       0
#
#                           class  boxes  x_2  y_2  x_center  y_center  area
# 0  No Lung Opacity / Not Normal      1  NaN  NaN       NaN       NaN   NaN
# 1  No Lung Opacity / Not Normal      1  NaN  NaN       NaN       NaN   NaN

# %%
box_count_sum = df_box.\
    groupby('boxes').\
    size().\
    reset_index(name='patients')
print('Group by the number of boxes')
print(box_count_sum.head(5))
box_count_sum.to_csv(os.path.join(procesed_data_DIR,'df_boxe_count_sum.csv'), index = False)
# Out:
# Group by the number of boxes
#    boxes  patients
# 0      1     23286
# 1      2      6532
# 2      3       357
# 3      4        52

# %% [markdown]
# #### 4.1) Let's check the sizes of bounding boxes

# %%
plot_box_size= sns.jointplot(x = 'width', y = 'height', data=df_box, kind ='hex', gridsize = 10,size =4)
plot_box_size.savefig(os.path.join(visul_DIR,'bounding_box_size.png'), figdpi = 600)

# %% [markdown]
# #### Where do the opacity regions are most likely to occur?

# %%
# select samples with Target ==1 
df_box_position = df_box.query('Target==1')
df_box_position.to_csv(os.path.join(procesed_data_DIR, 'df_box_position.csv'), index=False)
df_box_position.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9555 entries, 4 to 30226
# Data columns (total 13 columns):
# patientId    9555 non-null object
# x            9555 non-null float64
# y            9555 non-null float64
# width        9555 non-null float64
# height       9555 non-null float64
# Target       9555 non-null int64
# class        9555 non-null object
# boxes        9555 non-null int64
# x_2          9555 non-null float64
# y_2          9555 non-null float64
# x_center     9555 non-null float64
# y_center     9555 non-null float64
# area         9555 non-null float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 1.0+ MB

# %% [markdown]
# #### 4.2) Let's check the distribution of boxes

# %%
X_STEPS, Y_STEPS = 1024, 1024
xx, yy = np.meshgrid(np.linspace(0, 1024, X_STEPS),
           np.linspace(0, 1024, Y_STEPS), 
           indexing='xy')
distribution_img = np.zeros_like(xx)
for _, c_row in df_box_position.iterrows():
    c_mask = (xx>=c_row['x']) & (xx<=(c_row['x']+c_row['width']))
    c_mask &= (yy>=c_row['y']) & (yy<=c_row['y']+c_row['height'])
    distribution_img += c_mask
fig, ax1 = plt.subplots(1, 1, figsize = (5, 5))
ax1.imshow(distribution_img, cmap='hot')
fig.savefig(os.path.join(visul_DIR,'bounding_box_distribution.png'), figdpi = 600)

# %% [markdown]
# #### 5) Prepare a dataframe df_sum including all the information (df_path, Target, class, and boxes)

# %%
df_sum = pd.merge(df_box,df_path, on ='patientId', how ='left').sort_values('patientId')
print(df_sum.head(2))
print(df_sum.shape[0],'images and segmentations')
df_sum.to_csv(os.path.join(procesed_data_DIR, 'df_train_labels_infor_boxes_path_merge.csv'), index = False)
# Out:
#                                   patientId   x   y  width  height  Target  \
# 0      0004cfab-14fd-4e49-80ba-63a80b6bddd6 NaN NaN    NaN     NaN       0
# 28989  000924cf-0f8d-42bd-9158-1af53881a557 NaN NaN    NaN     NaN       0
#
#                               class  boxes  x_2  y_2  x_center  y_center  \
# 0      No Lung Opacity / Not Normal      1  NaN  NaN       NaN       NaN
# 28989                        Normal      1  NaN  NaN       NaN       NaN
#
#        area                                               path
# 0       NaN  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 28989   NaN  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 30227 images and segmentations

# %% [markdown]
# #### 6) Prepare a sample data set containing 6 samples (grouped by target, class and number or boxes)

# %%
df_sample = df_sum.\
    groupby(['Target','class', 'boxes']).\
    apply(lambda x: x[x['patientId']==x.sample(1)['patientId'].values[0]]).\
    sort_values(['Target','class','boxes'], ascending = True).\
    reset_index(drop=True)

print(df_sample['patientId'].nunique(), 'unique samples')
df_sample.to_csv(os.path.join(procesed_data_DIR, 'df_sample6.csv'),index = True)
df_sample
# Out:
# 6 unique samples
#                                patientId      x      y  width  height  Target  \
# 0   327a4509-9929-41b6-9e3d-d2bd90117d90    NaN    NaN    NaN     NaN       0
# 1   81cc48ed-0b64-436e-809e-47c3fc35006f    NaN    NaN    NaN     NaN       0
# 2   342bd0cf-b337-40e9-8512-eb170292e2f2  317.0  519.0  121.0   127.0       1
# 3   94c4e247-1228-4f50-b8b4-316754d5828f  391.0  357.0  194.0   222.0       1
# 4   94c4e247-1228-4f50-b8b4-316754d5828f  696.0  405.0  202.0   280.0       1
# 5   085a6486-c3b3-4ca2-80f1-be07d23e853b  665.0  231.0  185.0   284.0       1
# 6   085a6486-c3b3-4ca2-80f1-be07d23e853b  147.0  325.0  158.0   225.0       1
# 7   085a6486-c3b3-4ca2-80f1-be07d23e853b  332.0  422.0  155.0   249.0       1
# 8   32408669-c137-4e8d-bd62-fe8345b40e73  273.0  856.0  234.0   101.0       1
# 9   32408669-c137-4e8d-bd62-fe8345b40e73  702.0  801.0  249.0   144.0       1
# 10  32408669-c137-4e8d-bd62-fe8345b40e73  300.0  367.0  226.0   423.0       1
# 11  32408669-c137-4e8d-bd62-fe8345b40e73  706.0  360.0  232.0   238.0       1
#
#                            class  boxes    x_2    y_2  x_center  y_center  \
# 0   No Lung Opacity / Not Normal      1    NaN    NaN       NaN       NaN
# 1                         Normal      1    NaN    NaN       NaN       NaN
# 2                   Lung Opacity      1  438.0  646.0     377.5     582.5
# 3                   Lung Opacity      2  585.0  579.0     488.0     468.0
# 4                   Lung Opacity      2  898.0  685.0     797.0     545.0
# 5                   Lung Opacity      3  850.0  515.0     757.5     373.0
# 6                   Lung Opacity      3  305.0  550.0     226.0     437.5
# 7                   Lung Opacity      3  487.0  671.0     409.5     546.5
# 8                   Lung Opacity      4  507.0  957.0     390.0     906.5
# 9                   Lung Opacity      4  951.0  945.0     826.5     873.0
# 10                  Lung Opacity      4  526.0  790.0     413.0     578.5
# 11                  Lung Opacity      4  938.0  598.0     822.0     479.0
#
#        area                                               path
# 0       NaN  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 1       NaN  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 2   15367.0  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 3   43068.0  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 4   56560.0  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 5   52540.0  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 6   35550.0  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 7   38595.0  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 8   23634.0  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 9   35856.0  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 10  95598.0  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 11  55216.0  /home/ubuntu/healthcare/pneumonia_lungfish/src...

# %% [markdown]
# ## II. EDA of Images

# %% [markdown]
# #### 1) How does a pneumonia DICOM image look like?

# %%
# check an image with 4 boxes from the sample data set
file = pydicom.read_file(os.path.join(train_dicom_DIR,'8dc8e54b-5b05-4dac-80b9-fa48878621e2.dcm'))
#pt.imshow(file.pixel_array, cmap=plt.cm.bone) 
im = file.pixel_array
# Create figure and axes
fig,ax = plt.subplots(1)
# Display the image
ax.imshow(im)

# Add bounding boxes 
# Create a Rectangle patch (xy, width, height)
rect1 = patches.Rectangle((602,189),245,347,linewidth=1,edgecolor='r',facecolor='none')
rect2 = patches.Rectangle((199,492),267,452,linewidth=1,edgecolor='r',facecolor='none')
rect3 = patches.Rectangle((281,163),201,253, linewidth=1,edgecolor='r',facecolor='none')
rect4 = patches.Rectangle((688,548),187,181,linewidth=1,edgecolor='r',facecolor='none')
# Add the patch to the Axes
ax.add_patch(rect1)
ax.add_patch(rect2)
ax.add_patch(rect3)
ax.add_patch(rect4)
plt.show()
fig.savefig(os.path.join(visul_DIR,'8dc8e54b-5b05-4dac-80b9-fa48878621e2_postive_sampe.png'), figdpi = 600)

# %% [markdown]
# #### 2) Let's check a negative case

# %%
#doc
neg = pydicom.read_file(os.path.join(train_dicom_DIR,'5e01e86a-d042-4644-a101-359fc9c8f59e.dcm'))
#plt.imshow(file.pixel_array, cmap=plt.cm.bone) 
im2 = neg.pixel_array
# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(im)

# Create a Rectangle patch
# Add the patch to the Axes

plt.show()
fig.savefig(os.path.join(visul_DIR,'5e01e86a-d042-4644-a101-359fc9c8f59e_negative_sampe.png'), figdpi = 600)

# %% [markdown]
# #### 3) Overlay the distribution of boxes with 6 patients' images, and bounding boxes

# %%
fig, m_axs = plt.subplots(2, 3, figsize = (20, 10))

for c_ax, (c_path, c_rows) in zip(m_axs.flatten(),
                    df_sample.groupby(['path'])):
    c_img_arr = pydicom.read_file(c_path).pixel_array
    # overlay
    c_img = plt.cm.gray(c_img_arr)
    c_img += 0.25*plt.cm.hot(distribution_img/distribution_img.max())
    c_img = np.clip(c_img, 0, 1)
    c_ax.imshow(c_img)
    
    c_ax.set_title('{class}'.format(**c_rows.iloc[0,:]))
    for i, (_, c_row) in enumerate(c_rows.dropna().iterrows()):
        c_ax.plot(c_row['x'], c_row['y'], 's', label='{class}'.format(**c_row))
        c_ax.add_patch(patches.Rectangle(xy=(c_row['x'], c_row['y']),
                                width=c_row['width'],
                                height=c_row['height'], 
                                 alpha = 0.5,
                                fill=False))
        if i==0: c_ax.legend()
            
fig.savefig(os.path.join(visul_DIR,'6sample_distribution_boxes.png'), figdpi = 600)

# %% [markdown]
# ## III Model

# %% [markdown]
# #### Transfer learning using MASK_RCNN

# %% [markdown]
# #### Download and setup
# os.chdir('/home/ubuntu/healthcare/pneumonia_lungfish/src/')
# !git clone https://www.github.com/matterport/Mask_RCNN.git
# sys.path.append(os.path.join(src, 'Mask_RCNN'))
# os.chdir('Mask_RCNN/')
# !python setup.py -q install

# %%
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib

from mrcnn import visualize
from mrcnn.model import log

# %% [markdown]
# #### 1) Some setup functions and classes for Mask-RCNN
# * train_dicom is a list of the dicom image path and filenames
# * image_annotions is a dictionary of the annotations keyed by the filenames
# * parsing the dataset returns a list of the image filenames and the annotations dictionary

# %%
def get_dicom(dicom_dir):
    train_dicom = glob.glob(dicom_dir+'/'+'*.dcm') #a list of the dicom image path and filenames
    return list(set(train_dicom))

def parse_dataset(dicom_dir, anns): 
    image_fps = get_dicom(dicom_dir)
    image_annotations = {fp: [] for fp in image_fps} #a dictionary of the annotations keyed by the filenames
    for index, row in anns.iterrows(): 
        fp = os.path.join(dicom_dir, row['patientId'] + '.dcm')
        image_annotations[fp].append(row)
    return image_fps, image_annotations

# %% [markdown]
# #### Configuration

# %%
class DetectorConfig(Config):
    """Configuration for training pneumonia detection on the RSNA pneumonia dataset.
    Overrides values in the base Config class.
    """
    
    # Give the configuration a name  
    NAME = 'pneumonia'
    
    # Train on 1 GPU and 2 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 2 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 2
    
    BACKBONE = 'resnet50'
    
    NUM_CLASSES = 2  # background + 1 pneumonia classes
    
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256
    RPN_ANCHOR_SCALES = (16, 32, 64, 128)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 4
    DETECTION_MAX_INSTANCES = 3
    DETECTION_MIN_CONFIDENCE = 0.78  ## match target distribution
    DETECTION_NMS_THRESHOLD = 0.01

    STEPS_PER_EPOCH = 200

config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        3
# DETECTION_MIN_CONFIDENCE       0.78
# DETECTION_NMS_THRESHOLD        0.01
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  256
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  256
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [256 256   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               4
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           pneumonia
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                200
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
class DetectorDataset(utils.Dataset):
    """Dataset class for training pneumonia detection on the RSNA pneumonia dataset.
    """

    def __init__(self, image_fps, image_annotations, orig_height, orig_width):
        super().__init__(self)
        
        # Add classes
        self.add_class('pneumonia', 1, 'Lung Opacity')
        
        # add images 
        for i, fp in enumerate(image_fps):
            annotations = image_annotations[fp]
            self.add_image('pneumonia', image_id=i, path=fp, 
                           annotations=annotations, orig_height=orig_height, orig_width=orig_width)
            
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

    def load_image(self, image_id):
        info = self.image_info[image_id]
        fp = info['path']
        ds = pydicom.read_file(fp)
        image = ds.pixel_array
        # If grayscale. Convert to RGB for consistency.
        if len(image.shape) != 3 or image.shape[2] != 3:
            image = np.stack((image,) * 3, -1)
        return image

    def load_mask(self, image_id):
        info = self.image_info[image_id]
        annotations = info['annotations']
        count = len(annotations)
        if count == 0:
            mask = np.zeros((info['orig_height'], info['orig_width'], 1), dtype=np.uint8)
            class_ids = np.zeros((1,), dtype=np.int32)
        else:
            mask = np.zeros((info['orig_height'], info['orig_width'], count), dtype=np.uint8)
            class_ids = np.zeros((count,), dtype=np.int32)
            for i, a in enumerate(annotations):
                if a['Target'] == 1:
                    x = int(a['x'])
                    y = int(a['y'])
                    w = int(a['width'])
                    h = int(a['height'])
                    mask_instance = mask[:, :, i].copy()
                    cv2.rectangle(mask_instance, (x, y), (x+w, y+h), 255, -1)
                    mask[:, :, i] = mask_instance
                    class_ids[i] = 1
        return mask.astype(np.bool), class_ids.astype(np.int32)

# %%
def image_split(image_list, small_dataset_ratio):
    split_index = int((1 - float(small_dataset_ratio)) * len(image_list))
    
    sorted(image_list)
    random.seed(42)
    random.shuffle(image_list)
    
    image_fps_big = image_list[:split_index]
    image_fps_small = image_list[split_index:]
    return image_fps_big, image_fps_small

# %%
# set color for class
def get_colors_for_class_ids(class_ids):
    colors = []
    for class_id in class_ids:
        if class_id == 1:
            colors.append((.941, .204, .204))
    return colors

# %% [markdown]
# #### 2) Match training csv and images

# %%
df_sum = pd.read_csv(os.path.join(procesed_data_DIR, 'df_train_labels_infor_boxes_path_merge.csv'))
df_sum.head(2)
# Out:
#                               patientId   x   y  width  height  Target  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6 NaN NaN    NaN     NaN       0
# 1  000924cf-0f8d-42bd-9158-1af53881a557 NaN NaN    NaN     NaN       0
#
#                           class  boxes  x_2  y_2  x_center  y_center  area  \
# 0  No Lung Opacity / Not Normal      1  NaN  NaN       NaN       NaN   NaN
# 1                        Normal      1  NaN  NaN       NaN       NaN   NaN
#
#                                                 path
# 0  /home/ubuntu/healthcare/pneumonia_lungfish/src...
# 1  /home/ubuntu/healthcare/pneumonia_lungfish/src...

# %%
image_fps, image_annotations = parse_dataset(train_dicom_DIR, anns=df_sum)

# %% [markdown]
# #### 3） Prepare a sample image dataset for demo

# %%
image_fps_list_sample = list(image_fps[:1000])

# %% [markdown]
# #### 3.2) Split the dataset into train, validation and test (0.8:0.1:0.1)

# %%
# Split the sample image list into train vs val_test
image_fps_train, image_fps_val_test = image_split(image_fps_list_sample, 0.2)
print('train:',len(image_fps_train), ';', 'validation and test: ', len(image_fps_val_test))

# Split the val_test into validation and test
image_fps_val, image_fps_test = image_split(image_fps_val_test, 0.5)
print('validataion: ',len(image_fps_val), ';',' test: ', len(image_fps_test))
# Out:
# train: 800 ; validation and test:  200
# validataion:  100 ;  test:  100

# %% [markdown]
# #### 3.2) prepare the training dataset

# %%
# Original DICOM image size: 1024 x 1024
ORIG_SIZE = 1024

dataset_train = DetectorDataset(image_fps_train, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_train.prepare()

# prepare the validation dataset
dataset_val = DetectorDataset(image_fps_val, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_val.prepare()

# Show annotation(s) for a DICOM image 
test_fp = random.choice(image_fps_train)
image_annotations[test_fp]
# Out:
# [patientId                 3a6aa686-b3ea-4e24-86e4-3129c520131d
#  x                                                          NaN
#  y                                                          NaN
#  width                                                      NaN
#  height                                                     NaN
#  Target                                                       0
#  class                                                   Normal
#  boxes                                                        1
#  x_2                                                        NaN
#  y_2                                                        NaN
#  x_center                                                   NaN
#  y_center                                                   NaN
#  area                                                       NaN
#  path         /home/ubuntu/healthcare/pneumonia_lungfish/src...
#  Name: 4921, dtype: object]

# %% [markdown]
# #### 3.3 ) Training

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=models_working_DIR)

# Exclude the last layers because they require a matching

model.load_weights(COCO_WEIGHTS_PATH, by_name=True, exclude=["mrcnn_class_logits", "mrcnn_bbox_fc","mrcnn_bbox", "mrcnn_mask"])

# %%
# %%time

## train heads with higher lr to speedup the learning
model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE*6,
            epochs=2,
            layers='heads',
            augmentation=None)  ## no augmentation
# Out:
# Starting at epoch 0. LR=0.006
#
# Checkpoint Path: /home/ubuntu/healthcare/pneumonia_lungfish/src/models_working/pneumonia20190305T0854/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/2
# 200/200 [==============================] - 171s 853ms/step - loss: 1.8470 - rpn_class_loss: 0.0244 - rpn_bbox_loss: 0.5200 - mrcnn_class_loss: 0.2636 - mrcnn_bbox_loss: 0.5769 - mrcnn_mask_loss: 0.4620 - val_loss: 2.3482 - val_rpn_class_loss: 0.0186 - val_rpn_bbox_loss: 1.1717 - val_mrcnn_class_loss: 0.1435 - val_mrcnn_bbox_loss: 0.5824 - val_mrcnn_mask_loss: 0.4319
# Epoch 2/2
# 200/200 [==============================] - 117s 583ms/step - loss: 1.6170 - rpn_class_loss: 0.0174 - rpn_bbox_loss: 0.5044 - mrcnn_class_loss: 0.2305 - mrcnn_bbox_loss: 0.4572 - mrcnn_mask_loss: 0.4075 - val_loss: 1.8217 - val_rpn_class_loss: 0.0174 - val_rpn_bbox_loss: 0.4437 - val_mrcnn_class_loss: 0.2966 - val_mrcnn_bbox_loss: 0.6292 - val_mrcnn_mask_loss: 0.4349
# CPU times: user 3min 2s, sys: 6.14 s, total: 3min 8s
# Wall time: 5min 13s

# %%
history = model.keras_model.history.history
epochs = range(1,len(next(iter(history.values())))+1)
pd.DataFrame(history, index=epochs)
# Out:
#        loss  mrcnn_bbox_loss  mrcnn_class_loss  mrcnn_mask_loss  \
# 1  1.847040         0.576924          0.263628         0.462029
# 2  1.616993         0.457198          0.230507         0.407543
#
#    rpn_bbox_loss  rpn_class_loss  val_loss  val_mrcnn_bbox_loss  \
# 1       0.520016        0.024441  2.348162             0.582427
# 2       0.504375        0.017369  1.821725             0.629243
#
#    val_mrcnn_class_loss  val_mrcnn_mask_loss  val_rpn_bbox_loss  \
# 1              0.143499             0.431904           1.171724
# 2              0.296598             0.434861           0.443665
#
#    val_rpn_class_loss
# 1            0.018607
# 2            0.017357

# %% [markdown]
# model.get_trainable_layers()# 71 layers

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
plt.plot(epochs, history["loss"], label="Train loss")
plt.plot(epochs, history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(epochs, history["mrcnn_class_loss"], label="Train class ce")
plt.plot(epochs, history["val_mrcnn_class_loss"], label="Valid class ce")
plt.legend()
plt.subplot(133)
plt.plot(epochs, history["mrcnn_bbox_loss"], label="Train box loss")
plt.plot(epochs, history["val_mrcnn_bbox_loss"], label="Valid box loss")
plt.legend()

plt.show()

# %% [markdown]
# #### 3.4 ) Inference

# %%
model_path = os.path.join(models_working_DIR,'pneumonia20190305T0854','mask_rcnn_pneumonia_0002.h5')

# %%
model_path
# Out:
# '/home/ubuntu/healthcare/pneumonia_lungfish/src/models_working/pneumonia20190305T0854/mask_rcnn_pneumonia_0002.h5'

# %%
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=models_save_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)

# %%
#show few example of ground truth vs. predictions on the validation dataset 
dataset = dataset_val
fig = plt.figure(figsize=(10, 30))

for i in range(6):

    image_id = random.choice(dataset.image_ids)
    
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)
    
    #print(original_image.shape)
    plt.subplot(6, 2, 2*i + 1)
    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset.class_names,
                                colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
    
    plt.subplot(6, 2, 2*i + 2)
    results = model.detect([original_image]) #, verbose=1)
    r = results[0]
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset.class_names, r['scores'], 
                                colors=get_colors_for_class_ids(r['class_ids']), ax=fig.axes[-1])
    print(image_id)
# Out:
# *** No instances to display ***
#
# 30
#
# *** No instances to display ***
#
# 35
#
# *** No instances to display ***
#
# 85
#
# *** No instances to display ***
#
# 62
#
# *** No instances to display ***
#
# 27
#
# *** No instances to display ***
#
# 69

# %% [markdown]
# original_image,image_meta is an arry
# gt_class_id: array([1], dtype=int32)
# gt_bbox: gt_bbox
# gt_mask: array False
# dataset.class_names
# gt_class_id: array([1], dtype=int32)

# %% [markdown]
# {'rois': array([[149, 176, 183, 212],
#         [139,  47, 167,  82]], dtype=int32),
#  'class_ids': array([1, 1], dtype=int32),
#  'scores': array([0.9235355 , 0.86759233], dtype=float32),
#  'masks': array([[[False, False],

# %% [markdown]
# #### 3.5) Evaluation metrics

# %% [markdown]
# #### add to utils.py

# %% [markdown]
# #### 4) Training with full dataset Train: Validation: Test =0.9:0.05:0.05

# %%
image_fps_list = list(image_fps)

# %%
# Split the sample image list into train vs val_test
image_fps_train, image_fps_val_test = image_split(image_fps_list, 0.1)
print('train:',len(image_fps_train), ';', 'validation and test: ', len(image_fps_val_test))

# Split the val_test into validation and test
image_fps_val, image_fps_test = image_split(image_fps_list, 0.5)
print('validataion: ',len(image_fps_val), ';',' test: ', len(image_fps_test))
# Out:
# train: 24015 ; validation and test:  2669
# validataion:  13342 ;  test:  13342

# %%
# Original DICOM image size: 1024 x 1024
ORIG_SIZE = 1024

dataset_train = DetectorDataset(image_fps_train, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_train.prepare()

# prepare the validation dataset
dataset_val = DetectorDataset(image_fps_val, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_val.prepare()

# Show annotation(s) for a DICOM image 
test_fp = random.choice(image_fps_train)
image_annotations[test_fp]
# Out:
# [patientId                 d90addc3-4722-4df8-9dce-e6cd4fe804f6
#  x                                                          NaN
#  y                                                          NaN
#  width                                                      NaN
#  height                                                     NaN
#  Target                                                       0
#  class                             No Lung Opacity / Not Normal
#  boxes                                                        1
#  x_2                                                        NaN
#  y_2                                                        NaN
#  x_center                                                   NaN
#  y_center                                                   NaN
#  area                                                       NaN
#  path         /home/ubuntu/healthcare/pneumonia_lungfish/src...
#  Name: 25375, dtype: object]

# %% [markdown]
# #### 4.3)  Training

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=models_working_DIR)

# Exclude the last layers because they require a matching

model.load_weights(COCO_WEIGHTS_PATH, by_name=True, exclude=["mrcnn_class_logits", "mrcnn_bbox_fc","mrcnn_bbox", "mrcnn_mask"])

# %%
# %%time

## train heads with higher lr to speedup the learning
model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE*6,
            epochs=10,
            layers='heads',
            augmentation=None)  ## no augmentation
# Out:
# Starting at epoch 0. LR=0.006
#
# Checkpoint Path: /home/ubuntu/healthcare/pneumonia_lungfish/src/models_working/pneumonia20190305T1520/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/10
# 200/200 [==============================] - 169s 844ms/step - loss: 1.7958 - rpn_class_loss: 0.0250 - rpn_bbox_loss: 0.4692 - mrcnn_class_loss: 0.2806 - mrcnn_bbox_loss: 0.5692 - mrcnn_mask_loss: 0.4517 - val_loss: 2.3060 - val_rpn_class_loss: 0.0265 - val_rpn_bbox_loss: 1.0403 - val_mrcnn_class_loss: 0.2455 - val_mrcnn_bbox_loss: 0.5502 - val_mrcnn_mask_loss: 0.4436
# Epoch 2/10
# 200/200 [==============================] - 99s 497ms/step - loss: 1.6622 - rpn_class_loss: 0.0174 - rpn_bbox_loss: 0.5715 - mrcnn_class_loss: 0.2311 - mrcnn_bbox_loss: 0.4454 - mrcnn_mask_loss: 0.3969 - val_loss: 2.3720 - val_rpn_class_loss: 0.0158 - val_rpn_bbox_loss: 0.8110 - val_mrcnn_class_loss: 0.4400 - val_mrcnn_bbox_loss: 0.6521 - val_mrcnn_mask_loss: 0.4531
# Epoch 3/10
# 200/200 [==============================] - 101s 506ms/step - loss: 1.6285 - rpn_class_loss: 0.0172 - rpn_bbox_loss: 0.4742 - mrcnn_class_loss: 0.2701 - mrcnn_bbox_loss: 0.4593 - mrcnn_mask_loss: 0.4077 - val_loss: 2.1878 - val_rpn_class_loss: 0.0168 - val_rpn_bbox_loss: 1.1334 - val_mrcnn_class_loss: 0.2044 - val_mrcnn_bbox_loss: 0.4353 - val_mrcnn_mask_loss: 0.3980
# Epoch 4/10
# 200/200 [==============================] - 107s 536ms/step - loss: 1.7091 - rpn_class_loss: 0.0176 - rpn_bbox_loss: 0.6016 - mrcnn_class_loss: 0.2635 - mrcnn_bbox_loss: 0.4391 - mrcnn_mask_loss: 0.3873 - val_loss: 2.5398 - val_rpn_class_loss: 0.0199 - val_rpn_bbox_loss: 1.5442 - val_mrcnn_class_loss: 0.1573 - val_mrcnn_bbox_loss: 0.4519 - val_mrcnn_mask_loss: 0.3665
# Epoch 5/10
# 200/200 [==============================] - 100s 501ms/step - loss: 1.8157 - rpn_class_loss: 0.0161 - rpn_bbox_loss: 0.7060 - mrcnn_class_loss: 0.2740 - mrcnn_bbox_loss: 0.4398 - mrcnn_mask_loss: 0.3797 - val_loss: 1.8783 - val_rpn_class_loss: 0.0179 - val_rpn_bbox_loss: 0.5914 - val_mrcnn_class_loss: 0.2563 - val_mrcnn_bbox_loss: 0.5514 - val_mrcnn_mask_loss: 0.4613
# Epoch 6/10
# 200/200 [==============================] - 85s 426ms/step - loss: 1.7435 - rpn_class_loss: 0.0159 - rpn_bbox_loss: 0.6296 - mrcnn_class_loss: 0.2947 - mrcnn_bbox_loss: 0.4255 - mrcnn_mask_loss: 0.3777 - val_loss: 2.6449 - val_rpn_class_loss: 0.0196 - val_rpn_bbox_loss: 1.4364 - val_mrcnn_class_loss: 0.2125 - val_mrcnn_bbox_loss: 0.5579 - val_mrcnn_mask_loss: 0.4185
# Epoch 7/10
# 200/200 [==============================] - 90s 449ms/step - loss: 1.6192 - rpn_class_loss: 0.0150 - rpn_bbox_loss: 0.5601 - mrcnn_class_loss: 0.2629 - mrcnn_bbox_loss: 0.4099 - mrcnn_mask_loss: 0.3713 - val_loss: 2.6343 - val_rpn_class_loss: 0.0190 - val_rpn_bbox_loss: 1.4098 - val_mrcnn_class_loss: 0.2672 - val_mrcnn_bbox_loss: 0.5439 - val_mrcnn_mask_loss: 0.3943
# Epoch 8/10
# 200/200 [==============================] - 88s 439ms/step - loss: 1.6847 - rpn_class_loss: 0.0149 - rpn_bbox_loss: 0.6106 - mrcnn_class_loss: 0.2817 - mrcnn_bbox_loss: 0.4106 - mrcnn_mask_loss: 0.3670 - val_loss: 2.0861 - val_rpn_class_loss: 0.0153 - val_rpn_bbox_loss: 0.9513 - val_mrcnn_class_loss: 0.2948 - val_mrcnn_bbox_loss: 0.4321 - val_mrcnn_mask_loss: 0.3927
# Epoch 9/10
# 200/200 [==============================] - 87s 434ms/step - loss: 1.6037 - rpn_class_loss: 0.0142 - rpn_bbox_loss: 0.5596 - mrcnn_class_loss: 0.2720 - mrcnn_bbox_loss: 0.3907 - mrcnn_mask_loss: 0.3672 - val_loss: 2.6973 - val_rpn_class_loss: 0.0226 - val_rpn_bbox_loss: 1.6902 - val_mrcnn_class_loss: 0.1798 - val_mrcnn_bbox_loss: 0.4168 - val_mrcnn_mask_loss: 0.3879
# Epoch 10/10
# 200/200 [==============================] - 92s 459ms/step - loss: 1.6060 - rpn_class_loss: 0.0146 - rpn_bbox_loss: 0.5618 - mrcnn_class_loss: 0.2704 - mrcnn_bbox_loss: 0.3898 - mrcnn_mask_loss: 0.3695 - val_loss: 1.9386 - val_rpn_class_loss: 0.0127 - val_rpn_bbox_loss: 0.7325 - val_mrcnn_class_loss: 0.3517 - val_mrcnn_bbox_loss: 0.4364 - val_mrcnn_mask_loss: 0.4052
# CPU times: user 9min 55s, sys: 19.1 s, total: 10min 14s
# Wall time: 17min 36s

# %%
history = model.keras_model.history.history
epochs = range(1,len(next(iter(history.values())))+1)
pd.DataFrame(history, index=epochs)
# Out:
#         loss  mrcnn_bbox_loss  mrcnn_class_loss  mrcnn_mask_loss  \
# 1   1.795762         0.569212          0.280595         0.451680
# 2   1.662167         0.445361          0.231105         0.396855
# 3   1.628550         0.459283          0.270137         0.407742
# 4   1.709057         0.439081          0.263528         0.387298
# 5   1.815687         0.439758          0.274033         0.379732
# 6   1.743472         0.425525          0.294737         0.377665
# 7   1.619170         0.409936          0.262878         0.371283
# 8   1.684747         0.410577          0.281682         0.366953
# 9   1.603686         0.390671          0.272034         0.367161
# 10  1.606031         0.389756          0.270379         0.369507
#
#     rpn_bbox_loss  rpn_class_loss  val_loss  val_mrcnn_bbox_loss  \
# 1        0.469229        0.025044  2.306024             0.550179
# 2        0.571459        0.017386  2.371972             0.652063
# 3        0.474151        0.017234  2.187831             0.435264
# 4        0.601559        0.017587  2.539753             0.451914
# 5        0.706039        0.016122  1.878296             0.551401
# 6        0.629648        0.015893  2.644864             0.557933
# 7        0.560107        0.014960  2.634308             0.543941
# 8        0.610625        0.014904  2.086119             0.432099
# 9        0.559620        0.014192  2.697344             0.416830
# 10       0.561811        0.014567  1.938571             0.436418
#
#     val_mrcnn_class_loss  val_mrcnn_mask_loss  val_rpn_bbox_loss  \
# 1               0.245491             0.443589           1.040294
# 2               0.439981             0.453123           0.810967
# 3               0.204427             0.397980           1.133383
# 4               0.157280             0.366481           1.544154
# 5               0.256300             0.461253           0.591392
# 6               0.212495             0.418483           1.436383
# 7               0.267173             0.394340           1.409830
# 8               0.294787             0.392651           0.951259
# 9               0.179835             0.387889           1.690162
# 10              0.351713             0.405189           0.732524
#
#     val_rpn_class_loss
# 1             0.026468
# 2             0.015836
# 3             0.016775
# 4             0.019921
# 5             0.017946
# 6             0.019565
# 7             0.019018
# 8             0.015316
# 9             0.022618
# 10            0.012715

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
plt.plot(epochs, history["loss"], label="Train loss")
plt.plot(epochs, history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(epochs, history["mrcnn_class_loss"], label="Train class ce")
plt.plot(epochs, history["val_mrcnn_class_loss"], label="Valid class ce")
plt.legend()
plt.subplot(133)
plt.plot(epochs, history["mrcnn_bbox_loss"], label="Train box loss")
plt.plot(epochs, history["val_mrcnn_bbox_loss"], label="Valid box loss")
plt.legend()

plt.show()

# %% [markdown]
# #### 4) Inference

# %%
best_epoch = np.argmin(history["val_loss"])
print("Best Epoch:", best_epoch + 1, history["val_loss"][best_epoch])
# Out:
# Best Epoch: 5 1.8782963228225709

# %%
model_path = os.path.join(models_working_DIR,'pneumonia20190305T1520','mask_rcnn_pneumonia_0005.h5')

# %%
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=models_save_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/sparse_ops.py:1165: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# Loading weights from  /home/ubuntu/healthcare/pneumonia_lungfish/src/models_working/pneumonia20190305T1520/mask_rcnn_pneumonia_0005.h5
# Re-starting from epoch 5

# %%
#show few example of ground truth vs. predictions on the validation dataset 
dataset = dataset_val
fig = plt.figure(figsize=(10, 30))

for i in range(6):

    image_id = random.choice(dataset.image_ids)
    
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)
    
    #print(original_image.shape)
    plt.subplot(6, 2, 2*i + 1)
    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset.class_names,
                                colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
    
    plt.subplot(6, 2, 2*i + 2)
    results = model.detect([original_image]) #, verbose=1)
    r = results[0]
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset.class_names, r['scores'], 
                                colors=get_colors_for_class_ids(r['class_ids']), ax=fig.axes[-1])
    print(image_id)
# Out:
# *** No instances to display ***
#
# 3410
#
# *** No instances to display ***
#
# 12474
# 3568
#
# *** No instances to display ***
#
# 32
#
# *** No instances to display ***
#
# 998
#
# *** No instances to display ***
#
# 337

# %%
# Make predictions on test images, write out sample submission
def predict(image_fps, filepath='validation_result.csv', min_conf=0.95):
    # assume square image
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    #resize_factor = ORIG_SIZE
    with open(filepath, 'w') as file:
        file.write("patientId,PredictionString\n")

        for image_id in tqdm(image_fps):
            ds = pydicom.read_file(image_id)
            image = ds.pixel_array
            # If grayscale. Convert to RGB for consistency.
            if len(image.shape) != 3 or image.shape[2] != 3:
                image = np.stack((image,) * 3, -1)
            image, window, scale, padding, crop = utils.resize_image(
                image,
                min_dim=config.IMAGE_MIN_DIM,
                min_scale=config.IMAGE_MIN_SCALE,
                max_dim=config.IMAGE_MAX_DIM,
                mode=config.IMAGE_RESIZE_MODE)

            patient_id = os.path.splitext(os.path.basename(image_id))[0]

            results = model.detect([image])
            r = results[0]

            out_str = ""
            out_str += patient_id
            out_str += ","
            assert( len(r['rois']) == len(r['class_ids']) == len(r['scores']) )
            if len(r['rois']) == 0:
                pass
            else:
                num_instances = len(r['rois'])

                for i in range(num_instances):
                    if r['scores'][i] > min_conf:
                        out_str += ' '
                        out_str += str(round(r['scores'][i], 2))
                        out_str += ' '

                        # x1, y1, width, height
                        x1 = r['rois'][i][1]
                        y1 = r['rois'][i][0]
                        width = r['rois'][i][3] - x1
                        height = r['rois'][i][2] - y1
                        bboxes_str = "{} {} {} {}".format(x1*resize_factor, y1*resize_factor, \
                                                           width*resize_factor, height*resize_factor)
                        out_str += bboxes_str

            file.write(out_str+"\n")

# %%
validation_result_fp = os.path.join(validation_result_DIR, 'validation_result.csv')

# %%
predict(image_fps_val, filepath=validation_result_fp)
print(submission_fp)
# Out:
# 100%|██████████| 13342/13342 [35:33<00:00,  5.76it/s]
# /home/ubuntu/healthcare/pneumonia_lungfish/src/data/validation_result/validation_result.csv

# %%
output = pd.read_csv(validation_result_fp)
output.head(2)
# Out:
#                               patientId  \
# 0  73cf4830-0084-4a68-b115-22f713d1387d
# 1  da94e078-7185-4931-8373-2838f05066ec
#
#                                     PredictionString
# 0   1.0 596.0 552.0 208.0 232.0 0.99 580.0 160.0 ...
# 1   0.99 156.0 520.0 240.0 276.0 0.98 604.0 528.0...

# %%
##### 5) training using Rsnet101

# %%
class DetectorConfig(Config):
    """Configuration for training pneumonia detection on the RSNA pneumonia dataset.
    Overrides values in the base Config class.
    """
    
    # Give the configuration a name  
    NAME = 'pneumonia'
    
    # Train on 1 GPU and 2 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 2 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 2
    
    BACKBONE = 'resnet101'
    
    NUM_CLASSES = 2  # background + 1 pneumonia classes
    
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256
    RPN_ANCHOR_SCALES = (16, 32, 64, 128)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 4
    DETECTION_MAX_INSTANCES = 3
    DETECTION_MIN_CONFIDENCE = 0.78  ## match target distribution
    DETECTION_NMS_THRESHOLD = 0.01

    STEPS_PER_EPOCH = 200

config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        3
# DETECTION_MIN_CONFIDENCE       0.78
# DETECTION_NMS_THRESHOLD        0.01
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  256
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  256
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [256 256   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               4
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           pneumonia
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                200
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# #### 5.3) Training
# models are saved in pneumonia20190305T1924

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=models_working_DIR)

# Exclude the last layers because they require a matching

model.load_weights(COCO_WEIGHTS_PATH, by_name=True, exclude=["mrcnn_class_logits", "mrcnn_bbox_fc","mrcnn_bbox", "mrcnn_mask"])

# %%
# %%time

## train heads with higher lr to speedup the learning
model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE*6,
            epochs=10,
            layers='heads',
            augmentation=None)  ## no augmentation
# Out:
# Starting at epoch 0. LR=0.006
#
# Checkpoint Path: /home/ubuntu/healthcare/pneumonia_lungfish/src/models_working/pneumonia20190305T1924/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/10
# 200/200 [==============================] - 172s 861ms/step - loss: 2.1025 - rpn_class_loss: 0.0244 - rpn_bbox_loss: 0.6709 - mrcnn_class_loss: 0.3063 - mrcnn_bbox_loss: 0.6248 - mrcnn_mask_loss: 0.4760 - val_loss: 2.6501 - val_rpn_class_loss: 0.0245 - val_rpn_bbox_loss: 1.2371 - val_mrcnn_class_loss: 0.1626 - val_mrcnn_bbox_loss: 0.6953 - val_mrcnn_mask_loss: 0.5306
# Epoch 2/10
# 200/200 [==============================] - 108s 541ms/step - loss: 1.8215 - rpn_class_loss: 0.0207 - rpn_bbox_loss: 0.6251 - mrcnn_class_loss: 0.2117 - mrcnn_bbox_loss: 0.5249 - mrcnn_mask_loss: 0.4390 - val_loss: 2.0958 - val_rpn_class_loss: 0.0319 - val_rpn_bbox_loss: 0.6551 - val_mrcnn_class_loss: 0.3287 - val_mrcnn_bbox_loss: 0.6276 - val_mrcnn_mask_loss: 0.4525
# Epoch 3/10
# 200/200 [==============================] - 105s 524ms/step - loss: 1.7290 - rpn_class_loss: 0.0212 - rpn_bbox_loss: 0.5953 - mrcnn_class_loss: 0.2319 - mrcnn_bbox_loss: 0.4704 - mrcnn_mask_loss: 0.4103 - val_loss: 2.2890 - val_rpn_class_loss: 0.0182 - val_rpn_bbox_loss: 0.7077 - val_mrcnn_class_loss: 0.5622 - val_mrcnn_bbox_loss: 0.5554 - val_mrcnn_mask_loss: 0.4456
# Epoch 4/10
# 200/200 [==============================] - 101s 507ms/step - loss: 1.7880 - rpn_class_loss: 0.0206 - rpn_bbox_loss: 0.6702 - mrcnn_class_loss: 0.2407 - mrcnn_bbox_loss: 0.4604 - mrcnn_mask_loss: 0.3961 - val_loss: 2.8626 - val_rpn_class_loss: 0.0326 - val_rpn_bbox_loss: 1.6843 - val_mrcnn_class_loss: 0.1617 - val_mrcnn_bbox_loss: 0.5621 - val_mrcnn_mask_loss: 0.4219
# Epoch 5/10
# 200/200 [==============================] - 105s 527ms/step - loss: 1.6969 - rpn_class_loss: 0.0235 - rpn_bbox_loss: 0.5752 - mrcnn_class_loss: 0.2425 - mrcnn_bbox_loss: 0.4645 - mrcnn_mask_loss: 0.3912 - val_loss: 2.7906 - val_rpn_class_loss: 0.0286 - val_rpn_bbox_loss: 1.3620 - val_mrcnn_class_loss: 0.3969 - val_mrcnn_bbox_loss: 0.5615 - val_mrcnn_mask_loss: 0.4417
# Epoch 6/10
# 200/200 [==============================] - 104s 519ms/step - loss: 1.8518 - rpn_class_loss: 0.0243 - rpn_bbox_loss: 0.6660 - mrcnn_class_loss: 0.2708 - mrcnn_bbox_loss: 0.4951 - mrcnn_mask_loss: 0.3956 - val_loss: 2.4503 - val_rpn_class_loss: 0.0277 - val_rpn_bbox_loss: 1.1704 - val_mrcnn_class_loss: 0.2423 - val_mrcnn_bbox_loss: 0.5475 - val_mrcnn_mask_loss: 0.4624
# Epoch 7/10
# 200/200 [==============================] - 102s 511ms/step - loss: 2.0077 - rpn_class_loss: 0.0260 - rpn_bbox_loss: 0.8728 - mrcnn_class_loss: 0.2568 - mrcnn_bbox_loss: 0.4672 - mrcnn_mask_loss: 0.3849 - val_loss: 2.4813 - val_rpn_class_loss: 0.0428 - val_rpn_bbox_loss: 1.2685 - val_mrcnn_class_loss: 0.2332 - val_mrcnn_bbox_loss: 0.5290 - val_mrcnn_mask_loss: 0.4078
# Epoch 8/10
# 200/200 [==============================] - 110s 552ms/step - loss: 1.8559 - rpn_class_loss: 0.0253 - rpn_bbox_loss: 0.7902 - mrcnn_class_loss: 0.1876 - mrcnn_bbox_loss: 0.4648 - mrcnn_mask_loss: 0.3881 - val_loss: 5.7861 - val_rpn_class_loss: 0.0943 - val_rpn_bbox_loss: 4.5558 - val_mrcnn_class_loss: 0.2146 - val_mrcnn_bbox_loss: 0.5197 - val_mrcnn_mask_loss: 0.4018
# Epoch 9/10
# 200/200 [==============================] - 119s 597ms/step - loss: 1.7485 - rpn_class_loss: 0.0302 - rpn_bbox_loss: 0.6186 - mrcnn_class_loss: 0.2228 - mrcnn_bbox_loss: 0.4866 - mrcnn_mask_loss: 0.3902 - val_loss: 1.7925 - val_rpn_class_loss: 0.0198 - val_rpn_bbox_loss: 0.4932 - val_mrcnn_class_loss: 0.2775 - val_mrcnn_bbox_loss: 0.5973 - val_mrcnn_mask_loss: 0.4048
# Epoch 10/10
# 200/200 [==============================] - 115s 576ms/step - loss: 2.0782 - rpn_class_loss: 0.0326 - rpn_bbox_loss: 1.0217 - mrcnn_class_loss: 0.2122 - mrcnn_bbox_loss: 0.4402 - mrcnn_mask_loss: 0.3715 - val_loss: 2.7774 - val_rpn_class_loss: 0.0333 - val_rpn_bbox_loss: 1.7798 - val_mrcnn_class_loss: 0.1503 - val_mrcnn_bbox_loss: 0.4743 - val_mrcnn_mask_loss: 0.3397
# CPU times: user 12min 20s, sys: 20.8 s, total: 12min 41s
# Wall time: 19min 57s

# %%
history = model.keras_model.history.history
epochs = range(1,len(next(iter(history.values())))+1)
pd.DataFrame(history, index=epochs)
# Out:
#         loss  mrcnn_bbox_loss  mrcnn_class_loss  mrcnn_mask_loss  \
# 1   2.102454         0.624758          0.306342         0.476041
# 2   1.821466         0.524894          0.211748         0.439047
# 3   1.729047         0.470392          0.231909         0.410307
# 4   1.788045         0.460410          0.240743         0.396110
# 5   1.696878         0.464492          0.242515         0.391240
# 6   1.851778         0.495142          0.270750         0.395625
# 7   2.007736         0.467209          0.256796         0.384856
# 8   1.855947         0.464752          0.187575         0.388121
# 9   1.748462         0.486554          0.222834         0.390249
# 10  2.078196         0.440240          0.212173         0.371518
#
#     rpn_bbox_loss  rpn_class_loss  val_loss  val_mrcnn_bbox_loss  \
# 1        0.670946        0.024366  2.650057             0.695261
# 2        0.625065        0.020710  2.095770             0.627619
# 3        0.595256        0.021180  2.289044             0.555362
# 4        0.670165        0.020613  2.862630             0.562149
# 5        0.575166        0.023462  2.790612             0.561453
# 6        0.666006        0.024251  2.450298             0.547494
# 7        0.872823        0.026046  2.481329             0.529019
# 8        0.790222        0.025269  5.786089             0.519734
# 9        0.618580        0.030234  1.792487             0.597264
# 10       1.021683        0.032570  2.777399             0.474337
#
#     val_mrcnn_class_loss  val_mrcnn_mask_loss  val_rpn_bbox_loss  \
# 1               0.162562             0.530563           1.237129
# 2               0.328724             0.452473           0.655078
# 3               0.562216             0.445596           0.707660
# 4               0.161719             0.421895           1.684286
# 5               0.396937             0.441679           1.361977
# 6               0.242313             0.462351           1.170404
# 7               0.233203             0.407762           1.268527
# 8               0.214556             0.401771           4.555756
# 9               0.277475             0.404778           0.493204
# 10              0.150283             0.339694           1.779789
#
#     val_rpn_class_loss
# 1             0.024541
# 2             0.031873
# 3             0.018207
# 4             0.032578
# 5             0.028562
# 6             0.027731
# 7             0.042810
# 8             0.094262
# 9             0.019753
# 10            0.033283

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
plt.plot(epochs, history["loss"], label="Train loss")
plt.plot(epochs, history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(epochs, history["mrcnn_class_loss"], label="Train class ce")
plt.plot(epochs, history["val_mrcnn_class_loss"], label="Valid class ce")
plt.legend()
plt.subplot(133)
plt.plot(epochs, history["mrcnn_bbox_loss"], label="Train box loss")
plt.plot(epochs, history["val_mrcnn_bbox_loss"], label="Valid box loss")
plt.legend()

plt.show()

# %% [markdown]
# #### 5.4) Inference

# %%
best_epoch = np.argmin(history["val_loss"])
print("Best Epoch:", best_epoch + 1, history["val_loss"][best_epoch])
# Out:
# Best Epoch: 9 1.7924870300292968

# %%
model_path = os.path.join(models_working_DIR,'pneumonia20190305T1520','mask_rcnn_pneumonia_0005.h5')

# %% [markdown]
# #### 6) Resnet101, more layers, 4+

# %%
class DetectorConfig(Config):
    """Configuration for training pneumonia detection on the RSNA pneumonia dataset.
    Overrides values in the base Config class.
    """
    
    # Give the configuration a name  
    NAME = 'pneumonia'
    
    # Train on 1 GPU and 2 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 2 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 2
    
    BACKBONE = 'resnet101'
    
    NUM_CLASSES = 2  # background + 1 pneumonia classes
    
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256
    RPN_ANCHOR_SCALES = (16, 32, 64, 128)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 4
    DETECTION_MAX_INSTANCES = 3
    DETECTION_MIN_CONFIDENCE = 0.78  ## match target distribution
    DETECTION_NMS_THRESHOLD = 0.01

    STEPS_PER_EPOCH = 200

config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        3
# DETECTION_MIN_CONFIDENCE       0.78
# DETECTION_NMS_THRESHOLD        0.01
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  256
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  256
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [256 256   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               4
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           pneumonia
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                200
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=models_working_DIR)

# Exclude the last layers because they require a matching

model.load_weights(COCO_WEIGHTS_PATH, by_name=True, exclude=["mrcnn_class_logits", "mrcnn_bbox_fc","mrcnn_bbox", "mrcnn_mask"])

# %%
# %%time

## train heads with higher lr to speedup the learning
model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE*6,
            epochs=10,
            layers='4+',
            augmentation=None)  ## no augmentation
# Out:
# Starting at epoch 0. LR=0.006
#
# Checkpoint Path: /home/ubuntu/healthcare/pneumonia_lungfish/src/models_working/pneumonia20190305T1956/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res4g_branch2a         (Conv2D)
# bn4g_branch2a          (BatchNorm)
# res4g_branch2b         (Conv2D)
# bn4g_branch2b          (BatchNorm)
# res4g_branch2c         (Conv2D)
# bn4g_branch2c          (BatchNorm)
# res4h_branch2a         (Conv2D)
# bn4h_branch2a          (BatchNorm)
# res4h_branch2b         (Conv2D)
# bn4h_branch2b          (BatchNorm)
# res4h_branch2c         (Conv2D)
# bn4h_branch2c          (BatchNorm)
# res4i_branch2a         (Conv2D)
# bn4i_branch2a          (BatchNorm)
# res4i_branch2b         (Conv2D)
# bn4i_branch2b          (BatchNorm)
# res4i_branch2c         (Conv2D)
# bn4i_branch2c          (BatchNorm)
# res4j_branch2a         (Conv2D)
# bn4j_branch2a          (BatchNorm)
# res4j_branch2b         (Conv2D)
# bn4j_branch2b          (BatchNorm)
# res4j_branch2c         (Conv2D)
# bn4j_branch2c          (BatchNorm)
# res4k_branch2a         (Conv2D)
# bn4k_branch2a          (BatchNorm)
# res4k_branch2b         (Conv2D)
# bn4k_branch2b          (BatchNorm)
# res4k_branch2c         (Conv2D)
# bn4k_branch2c          (BatchNorm)
# res4l_branch2a         (Conv2D)
# bn4l_branch2a          (BatchNorm)
# res4l_branch2b         (Conv2D)
# bn4l_branch2b          (BatchNorm)
# res4l_branch2c         (Conv2D)
# bn4l_branch2c          (BatchNorm)
# res4m_branch2a         (Conv2D)
# bn4m_branch2a          (BatchNorm)
# res4m_branch2b         (Conv2D)
# bn4m_branch2b          (BatchNorm)
# res4m_branch2c         (Conv2D)
# bn4m_branch2c          (BatchNorm)
# res4n_branch2a         (Conv2D)
# bn4n_branch2a          (BatchNorm)
# res4n_branch2b         (Conv2D)
# bn4n_branch2b          (BatchNorm)
# res4n_branch2c         (Conv2D)
# bn4n_branch2c          (BatchNorm)
# res4o_branch2a         (Conv2D)
# bn4o_branch2a          (BatchNorm)
# res4o_branch2b         (Conv2D)
# bn4o_branch2b          (BatchNorm)
# res4o_branch2c         (Conv2D)
# bn4o_branch2c          (BatchNorm)
# res4p_branch2a         (Conv2D)
# bn4p_branch2a          (BatchNorm)
# res4p_branch2b         (Conv2D)
# bn4p_branch2b          (BatchNorm)
# res4p_branch2c         (Conv2D)
# bn4p_branch2c          (BatchNorm)
# res4q_branch2a         (Conv2D)
# bn4q_branch2a          (BatchNorm)
# res4q_branch2b         (Conv2D)
# bn4q_branch2b          (BatchNorm)
# res4q_branch2c         (Conv2D)
# bn4q_branch2c          (BatchNorm)
# res4r_branch2a         (Conv2D)
# bn4r_branch2a          (BatchNorm)
# res4r_branch2b         (Conv2D)
# bn4r_branch2b          (BatchNorm)
# res4r_branch2c         (Conv2D)
# bn4r_branch2c          (BatchNorm)
# res4s_branch2a         (Conv2D)
# bn4s_branch2a          (BatchNorm)
# res4s_branch2b         (Conv2D)
# bn4s_branch2b          (BatchNorm)
# res4s_branch2c         (Conv2D)
# bn4s_branch2c          (BatchNorm)
# res4t_branch2a         (Conv2D)
# bn4t_branch2a          (BatchNorm)
# res4t_branch2b         (Conv2D)
# bn4t_branch2b          (BatchNorm)
# res4t_branch2c         (Conv2D)
# bn4t_branch2c          (BatchNorm)
# res4u_branch2a         (Conv2D)
# bn4u_branch2a          (BatchNorm)
# res4u_branch2b         (Conv2D)
# bn4u_branch2b          (BatchNorm)
# res4u_branch2c         (Conv2D)
# bn4u_branch2c          (BatchNorm)
# res4v_branch2a         (Conv2D)
# bn4v_branch2a          (BatchNorm)
# res4v_branch2b         (Conv2D)
# bn4v_branch2b          (BatchNorm)
# res4v_branch2c         (Conv2D)
# bn4v_branch2c          (BatchNorm)
# res4w_branch2a         (Conv2D)
# bn4w_branch2a          (BatchNorm)
# res4w_branch2b         (Conv2D)
# bn4w_branch2b          (BatchNorm)
# res4w_branch2c         (Conv2D)
# bn4w_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/10
# 200/200 [==============================] - 226s 1s/step - loss: 1.8257 - rpn_class_loss: 0.0193 - rpn_bbox_loss: 0.5207 - mrcnn_class_loss: 0.2688 - mrcnn_bbox_loss: 0.5863 - mrcnn_mask_loss: 0.4307 - val_loss: 2.2540 - val_rpn_class_loss: 0.0194 - val_rpn_bbox_loss: 1.1074 - val_mrcnn_class_loss: 0.1745 - val_mrcnn_bbox_loss: 0.5165 - val_mrcnn_mask_loss: 0.4362
# Epoch 2/10
# 200/200 [==============================] - 156s 779ms/step - loss: 1.4574 - rpn_class_loss: 0.0159 - rpn_bbox_loss: 0.4479 - mrcnn_class_loss: 0.1941 - mrcnn_bbox_loss: 0.4205 - mrcnn_mask_loss: 0.3789 - val_loss: 2.9774 - val_rpn_class_loss: 0.0207 - val_rpn_bbox_loss: 1.9310 - val_mrcnn_class_loss: 0.0784 - val_mrcnn_bbox_loss: 0.5006 - val_mrcnn_mask_loss: 0.4466
# Epoch 3/10
# 200/200 [==============================] - 147s 734ms/step - loss: 1.4350 - rpn_class_loss: 0.0139 - rpn_bbox_loss: 0.4784 - mrcnn_class_loss: 0.1725 - mrcnn_bbox_loss: 0.3931 - mrcnn_mask_loss: 0.3771 - val_loss: 2.5474 - val_rpn_class_loss: 0.0241 - val_rpn_bbox_loss: 1.3389 - val_mrcnn_class_loss: 0.1742 - val_mrcnn_bbox_loss: 0.5441 - val_mrcnn_mask_loss: 0.4660
# Epoch 4/10
# 200/200 [==============================] - 152s 762ms/step - loss: 1.6596 - rpn_class_loss: 0.0138 - rpn_bbox_loss: 0.6161 - mrcnn_class_loss: 0.1923 - mrcnn_bbox_loss: 0.4407 - mrcnn_mask_loss: 0.3966 - val_loss: 2.0003 - val_rpn_class_loss: 0.0152 - val_rpn_bbox_loss: 1.0177 - val_mrcnn_class_loss: 0.1357 - val_mrcnn_bbox_loss: 0.4337 - val_mrcnn_mask_loss: 0.3980
# Epoch 5/10
# 200/200 [==============================] - 152s 760ms/step - loss: 1.4299 - rpn_class_loss: 0.0136 - rpn_bbox_loss: 0.4723 - mrcnn_class_loss: 0.1718 - mrcnn_bbox_loss: 0.3977 - mrcnn_mask_loss: 0.3745 - val_loss: 1.6462 - val_rpn_class_loss: 0.0155 - val_rpn_bbox_loss: 0.6244 - val_mrcnn_class_loss: 0.2103 - val_mrcnn_bbox_loss: 0.4303 - val_mrcnn_mask_loss: 0.3658
# Epoch 6/10
# 200/200 [==============================] - 150s 749ms/step - loss: 1.2601 - rpn_class_loss: 0.0112 - rpn_bbox_loss: 0.3808 - mrcnn_class_loss: 0.1526 - mrcnn_bbox_loss: 0.3561 - mrcnn_mask_loss: 0.3594 - val_loss: 2.1308 - val_rpn_class_loss: 0.0192 - val_rpn_bbox_loss: 1.1204 - val_mrcnn_class_loss: 0.1335 - val_mrcnn_bbox_loss: 0.4461 - val_mrcnn_mask_loss: 0.4116
# Epoch 7/10
# 200/200 [==============================] - 152s 759ms/step - loss: 1.2904 - rpn_class_loss: 0.0119 - rpn_bbox_loss: 0.3806 - mrcnn_class_loss: 0.1716 - mrcnn_bbox_loss: 0.3637 - mrcnn_mask_loss: 0.3626 - val_loss: 1.4674 - val_rpn_class_loss: 0.0155 - val_rpn_bbox_loss: 0.4623 - val_mrcnn_class_loss: 0.1818 - val_mrcnn_bbox_loss: 0.3995 - val_mrcnn_mask_loss: 0.4083
# Epoch 8/10
# 200/200 [==============================] - 151s 756ms/step - loss: 1.3113 - rpn_class_loss: 0.0107 - rpn_bbox_loss: 0.4066 - mrcnn_class_loss: 0.1655 - mrcnn_bbox_loss: 0.3568 - mrcnn_mask_loss: 0.3716 - val_loss: 1.5399 - val_rpn_class_loss: 0.0118 - val_rpn_bbox_loss: 0.4318 - val_mrcnn_class_loss: 0.2300 - val_mrcnn_bbox_loss: 0.4457 - val_mrcnn_mask_loss: 0.4206
# Epoch 9/10
# 200/200 [==============================] - 146s 729ms/step - loss: 1.3469 - rpn_class_loss: 0.0116 - rpn_bbox_loss: 0.4101 - mrcnn_class_loss: 0.1918 - mrcnn_bbox_loss: 0.3612 - mrcnn_mask_loss: 0.3722 - val_loss: 2.3658 - val_rpn_class_loss: 0.0201 - val_rpn_bbox_loss: 1.2578 - val_mrcnn_class_loss: 0.0975 - val_mrcnn_bbox_loss: 0.5196 - val_mrcnn_mask_loss: 0.4708
# Epoch 10/10
# 200/200 [==============================] - 149s 747ms/step - loss: 1.3443 - rpn_class_loss: 0.0112 - rpn_bbox_loss: 0.4202 - mrcnn_class_loss: 0.1644 - mrcnn_bbox_loss: 0.3761 - mrcnn_mask_loss: 0.3723 - val_loss: 1.8769 - val_rpn_class_loss: 0.0148 - val_rpn_bbox_loss: 0.5567 - val_mrcnn_class_loss: 0.3019 - val_mrcnn_bbox_loss: 0.5358 - val_mrcnn_mask_loss: 0.4677
# CPU times: user 19min 15s, sys: 33.6 s, total: 19min 49s
# Wall time: 28min 36s

# %%
history = model.keras_model.history.history
epochs = range(1,len(next(iter(history.values())))+1)
pd.DataFrame(history, index=epochs)
# Out:
#         loss  mrcnn_bbox_loss  mrcnn_class_loss  mrcnn_mask_loss  \
# 1   1.825708         0.586276          0.268771         0.430656
# 2   1.457362         0.420491          0.194084         0.378950
# 3   1.434956         0.393148          0.172503         0.377063
# 4   1.659559         0.440735          0.192348         0.396615
# 5   1.429906         0.397658          0.171818         0.374487
# 6   1.260119         0.356124          0.152599         0.359409
# 7   1.290356         0.363719          0.171614         0.362594
# 8   1.311312         0.356827          0.165508         0.371633
# 9   1.346877         0.361181          0.191781         0.372212
# 10  1.344277         0.376117          0.164440         0.372272
#
#     rpn_bbox_loss  rpn_class_loss  val_loss  val_mrcnn_bbox_loss  \
# 1        0.520701        0.019301  2.253967             0.516486
# 2        0.447925        0.015910  2.977356             0.500647
# 3        0.478376        0.013863  2.547398             0.544143
# 4        0.616101        0.013758  2.000258             0.433669
# 5        0.472303        0.013636  1.646243             0.430283
# 6        0.380769        0.011215  2.130765             0.446125
# 7        0.380570        0.011855  1.467444             0.399475
# 8        0.406646        0.010694  1.539948             0.445747
# 9        0.410119        0.011580  2.365799             0.519587
# 10       0.420247        0.011195  1.876865             0.535805
#
#     val_mrcnn_class_loss  val_mrcnn_mask_loss  val_rpn_bbox_loss  \
# 1               0.174453             0.436216           1.107414
# 2               0.078374             0.446611           1.931014
# 3               0.174220             0.466025           1.338943
# 4               0.135657             0.397997           1.017740
# 5               0.210252             0.365794           0.624384
# 6               0.133474             0.411559           1.120440
# 7               0.181837             0.408321           0.462293
# 8               0.230002             0.420578           0.431768
# 9               0.097522             0.470776           1.257849
# 10              0.301861             0.467650           0.556707
#
#     val_rpn_class_loss
# 1             0.019395
# 2             0.020707
# 3             0.024065
# 4             0.015192
# 5             0.015527
# 6             0.019163
# 7             0.015514
# 8             0.011850
# 9             0.020061
# 10            0.014837

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
plt.plot(epochs, history["loss"], label="Train loss")
plt.plot(epochs, history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(epochs, history["mrcnn_class_loss"], label="Train class ce")
plt.plot(epochs, history["val_mrcnn_class_loss"], label="Valid class ce")
plt.legend()
plt.subplot(133)
plt.plot(epochs, history["mrcnn_bbox_loss"], label="Train box loss")
plt.plot(epochs, history["val_mrcnn_bbox_loss"], label="Valid box loss")
plt.legend()

plt.show()

# %%
best_epoch = np.argmin(history["val_loss"])
print("Best Epoch:", best_epoch + 1, history["val_loss"][best_epoch])
# Out:
# Best Epoch: 7 1.467443701028824

# %% [markdown]
# #### 6.4) Inference

# %%
pneumonia20190305T1956_mask_rcnn_pneumonia_0007

# %%
model_path = os.path.join(models_working_DIR,'pneumonia20190305T1956','mask_rcnn_pneumonia_0007.h5')
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=models_save_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  /home/ubuntu/healthcare/pneumonia_lungfish/src/models_working/pneumonia20190305T1956/mask_rcnn_pneumonia_0007.h5
# Re-starting from epoch 7

# %%
submission_fp = os.path.join(ktest_data_DIR, 'submission.csv')
test_dicom_dir = '/home/ubuntu/healthcare/pneumonia_lungfish/src/data/test'
test_image_fps = get_dicom(test_dicom_dir)
predict(test_image_fps, filepath=submission_fp)
print(submission_fp)
output = pd.read_csv(submission_fp)
output.head(5)
# Out:
# /home/ubuntu/healthcare/pneumonia_lungfish/src/data/ktest/submission.csv
#                               patientId  \
# 0  3135b442-13ea-496f-b5ba-e0e074494c16
# 1  04026d9e-895d-4b87-9d73-3d6fb58e53a3
# 2  c0cdf524-c836-423b-aee6-65afc46567db
# 3  0d0a219a-f091-430b-a0c4-6a90faa1636c
# 4  2e00f7b7-ea1d-4da8-baa1-ffcbcc60be8d
#
#                                     PredictionString
# 0   0.99 264.0 396.0 176.0 232.0 0.99 624.0 484.0...
# 1   0.99 168.0 488.0 220.0 264.0 0.97 548.0 304.0...
# 2   0.99 300.0 392.0 168.0 224.0 0.98 692.0 228.0...
# 3   0.97 528.0 300.0 172.0 268.0 0.95 212.0 316.0...
# 4   0.99 304.0 592.0 136.0 168.0 0.97 676.0 564.0...

# %% [markdown]
# #### 7) Resnet101,try all layers

# %%
# %%time

## train heads with higher lr to speedup the learning
model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE*6,
            epochs=10,
            layers='all',
            augmentation=None)  ## no augmentation
# Out:
# Starting at epoch 0. LR=0.006
#
# Checkpoint Path: /home/ubuntu/healthcare/pneumonia_lungfish/src/models_working/pneumonia20190305T2032/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res4g_branch2a         (Conv2D)
# bn4g_branch2a          (BatchNorm)
# res4g_branch2b         (Conv2D)
# bn4g_branch2b          (BatchNorm)
# res4g_branch2c         (Conv2D)
# bn4g_branch2c          (BatchNorm)
# res4h_branch2a         (Conv2D)
# bn4h_branch2a          (BatchNorm)
# res4h_branch2b         (Conv2D)
# bn4h_branch2b          (BatchNorm)
# res4h_branch2c         (Conv2D)
# bn4h_branch2c          (BatchNorm)
# res4i_branch2a         (Conv2D)
# bn4i_branch2a          (BatchNorm)
# res4i_branch2b         (Conv2D)
# bn4i_branch2b          (BatchNorm)
# res4i_branch2c         (Conv2D)
# bn4i_branch2c          (BatchNorm)
# res4j_branch2a         (Conv2D)
# bn4j_branch2a          (BatchNorm)
# res4j_branch2b         (Conv2D)
# bn4j_branch2b          (BatchNorm)
# res4j_branch2c         (Conv2D)
# bn4j_branch2c          (BatchNorm)
# res4k_branch2a         (Conv2D)
# bn4k_branch2a          (BatchNorm)
# res4k_branch2b         (Conv2D)
# bn4k_branch2b          (BatchNorm)
# res4k_branch2c         (Conv2D)
# bn4k_branch2c          (BatchNorm)
# res4l_branch2a         (Conv2D)
# bn4l_branch2a          (BatchNorm)
# res4l_branch2b         (Conv2D)
# bn4l_branch2b          (BatchNorm)
# res4l_branch2c         (Conv2D)
# bn4l_branch2c          (BatchNorm)
# res4m_branch2a         (Conv2D)
# bn4m_branch2a          (BatchNorm)
# res4m_branch2b         (Conv2D)
# bn4m_branch2b          (BatchNorm)
# res4m_branch2c         (Conv2D)
# bn4m_branch2c          (BatchNorm)
# res4n_branch2a         (Conv2D)
# bn4n_branch2a          (BatchNorm)
# res4n_branch2b         (Conv2D)
# bn4n_branch2b          (BatchNorm)
# res4n_branch2c         (Conv2D)
# bn4n_branch2c          (BatchNorm)
# res4o_branch2a         (Conv2D)
# bn4o_branch2a          (BatchNorm)
# res4o_branch2b         (Conv2D)
# bn4o_branch2b          (BatchNorm)
# res4o_branch2c         (Conv2D)
# bn4o_branch2c          (BatchNorm)
# res4p_branch2a         (Conv2D)
# bn4p_branch2a          (BatchNorm)
# res4p_branch2b         (Conv2D)
# bn4p_branch2b          (BatchNorm)
# res4p_branch2c         (Conv2D)
# bn4p_branch2c          (BatchNorm)
# res4q_branch2a         (Conv2D)
# bn4q_branch2a          (BatchNorm)
# res4q_branch2b         (Conv2D)
# bn4q_branch2b          (BatchNorm)
# res4q_branch2c         (Conv2D)
# bn4q_branch2c          (BatchNorm)
# res4r_branch2a         (Conv2D)
# bn4r_branch2a          (BatchNorm)
# res4r_branch2b         (Conv2D)
# bn4r_branch2b          (BatchNorm)
# res4r_branch2c         (Conv2D)
# bn4r_branch2c          (BatchNorm)
# res4s_branch2a         (Conv2D)
# bn4s_branch2a          (BatchNorm)
# res4s_branch2b         (Conv2D)
# bn4s_branch2b          (BatchNorm)
# res4s_branch2c         (Conv2D)
# bn4s_branch2c          (BatchNorm)
# res4t_branch2a         (Conv2D)
# bn4t_branch2a          (BatchNorm)
# res4t_branch2b         (Conv2D)
# bn4t_branch2b          (BatchNorm)
# res4t_branch2c         (Conv2D)
# bn4t_branch2c          (BatchNorm)
# res4u_branch2a         (Conv2D)
# bn4u_branch2a          (BatchNorm)
# res4u_branch2b         (Conv2D)
# bn4u_branch2b          (BatchNorm)
# res4u_branch2c         (Conv2D)
# bn4u_branch2c          (BatchNorm)
# res4v_branch2a         (Conv2D)
# bn4v_branch2a          (BatchNorm)
# res4v_branch2b         (Conv2D)
# bn4v_branch2b          (BatchNorm)
# res4v_branch2c         (Conv2D)
# bn4v_branch2c          (BatchNorm)
# res4w_branch2a         (Conv2D)
# bn4w_branch2a          (BatchNorm)
# res4w_branch2b         (Conv2D)
# bn4w_branch2b          (BatchNorm)
# res4w_branch2c         (Conv2D)
# bn4w_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/10
# 200/200 [==============================] - 238s 1s/step - loss: 1.7884 - rpn_class_loss: 0.0188 - rpn_bbox_loss: 0.5164 - mrcnn_class_loss: 0.2899 - mrcnn_bbox_loss: 0.5245 - mrcnn_mask_loss: 0.4388 - val_loss: 1.8587 - val_rpn_class_loss: 0.0221 - val_rpn_bbox_loss: 0.3805 - val_mrcnn_class_loss: 0.4335 - val_mrcnn_bbox_loss: 0.5880 - val_mrcnn_mask_loss: 0.4345
# Epoch 2/10
# 200/200 [==============================] - 164s 819ms/step - loss: 1.5713 - rpn_class_loss: 0.0159 - rpn_bbox_loss: 0.4980 - mrcnn_class_loss: 0.2387 - mrcnn_bbox_loss: 0.4419 - mrcnn_mask_loss: 0.3768 - val_loss: 2.3920 - val_rpn_class_loss: 0.0212 - val_rpn_bbox_loss: 1.1389 - val_mrcnn_class_loss: 0.1535 - val_mrcnn_bbox_loss: 0.5673 - val_mrcnn_mask_loss: 0.5112
# Epoch 3/10
# 200/200 [==============================] - 163s 814ms/step - loss: 1.2998 - rpn_class_loss: 0.0106 - rpn_bbox_loss: 0.4039 - mrcnn_class_loss: 0.1556 - mrcnn_bbox_loss: 0.3693 - mrcnn_mask_loss: 0.3603 - val_loss: 2.0502 - val_rpn_class_loss: 0.0102 - val_rpn_bbox_loss: 1.1350 - val_mrcnn_class_loss: 0.0863 - val_mrcnn_bbox_loss: 0.4023 - val_mrcnn_mask_loss: 0.4163
# Epoch 4/10
# 200/200 [==============================] - 167s 837ms/step - loss: 1.3129 - rpn_class_loss: 0.0115 - rpn_bbox_loss: 0.4367 - mrcnn_class_loss: 0.1597 - mrcnn_bbox_loss: 0.3528 - mrcnn_mask_loss: 0.3521 - val_loss: 1.9748 - val_rpn_class_loss: 0.0165 - val_rpn_bbox_loss: 0.6872 - val_mrcnn_class_loss: 0.2563 - val_mrcnn_bbox_loss: 0.5548 - val_mrcnn_mask_loss: 0.4600
# Epoch 5/10
# 200/200 [==============================] - 158s 792ms/step - loss: 1.2858 - rpn_class_loss: 0.0115 - rpn_bbox_loss: 0.3892 - mrcnn_class_loss: 0.1717 - mrcnn_bbox_loss: 0.3522 - mrcnn_mask_loss: 0.3612 - val_loss: 1.7619 - val_rpn_class_loss: 0.0120 - val_rpn_bbox_loss: 0.6215 - val_mrcnn_class_loss: 0.2301 - val_mrcnn_bbox_loss: 0.4464 - val_mrcnn_mask_loss: 0.4519
# Epoch 6/10
# 200/200 [==============================] - 151s 756ms/step - loss: 1.3256 - rpn_class_loss: 0.0106 - rpn_bbox_loss: 0.4135 - mrcnn_class_loss: 0.1884 - mrcnn_bbox_loss: 0.3493 - mrcnn_mask_loss: 0.3637 - val_loss: 1.5674 - val_rpn_class_loss: 0.0130 - val_rpn_bbox_loss: 0.5085 - val_mrcnn_class_loss: 0.2002 - val_mrcnn_bbox_loss: 0.4364 - val_mrcnn_mask_loss: 0.4094
# Epoch 7/10
# 200/200 [==============================] - 151s 753ms/step - loss: 1.2891 - rpn_class_loss: 0.0105 - rpn_bbox_loss: 0.3752 - mrcnn_class_loss: 0.1887 - mrcnn_bbox_loss: 0.3523 - mrcnn_mask_loss: 0.3624 - val_loss: 1.9932 - val_rpn_class_loss: 0.0213 - val_rpn_bbox_loss: 0.7844 - val_mrcnn_class_loss: 0.2090 - val_mrcnn_bbox_loss: 0.5249 - val_mrcnn_mask_loss: 0.4535
# Epoch 8/10
# 200/200 [==============================] - 145s 725ms/step - loss: 1.2611 - rpn_class_loss: 0.0104 - rpn_bbox_loss: 0.3621 - mrcnn_class_loss: 0.1904 - mrcnn_bbox_loss: 0.3404 - mrcnn_mask_loss: 0.3577 - val_loss: 1.7057 - val_rpn_class_loss: 0.0140 - val_rpn_bbox_loss: 0.6823 - val_mrcnn_class_loss: 0.2899 - val_mrcnn_bbox_loss: 0.3698 - val_mrcnn_mask_loss: 0.3496
# Epoch 9/10
# 200/200 [==============================] - 143s 715ms/step - loss: 1.2972 - rpn_class_loss: 0.0111 - rpn_bbox_loss: 0.3692 - mrcnn_class_loss: 0.2107 - mrcnn_bbox_loss: 0.3476 - mrcnn_mask_loss: 0.3585 - val_loss: 2.0429 - val_rpn_class_loss: 0.0157 - val_rpn_bbox_loss: 0.9330 - val_mrcnn_class_loss: 0.2405 - val_mrcnn_bbox_loss: 0.4395 - val_mrcnn_mask_loss: 0.4141
# Epoch 10/10
# 200/200 [==============================] - 150s 748ms/step - loss: 1.2142 - rpn_class_loss: 0.0109 - rpn_bbox_loss: 0.3282 - mrcnn_class_loss: 0.1839 - mrcnn_bbox_loss: 0.3355 - mrcnn_mask_loss: 0.3557 - val_loss: 1.5250 - val_rpn_class_loss: 0.0083 - val_rpn_bbox_loss: 0.4702 - val_mrcnn_class_loss: 0.2039 - val_mrcnn_bbox_loss: 0.4350 - val_mrcnn_mask_loss: 0.4077
# CPU times: user 20min 23s, sys: 1min 11s, total: 21min 35s
# Wall time: 30min 44s

# %%
history = model.keras_model.history.history
epochs = range(1,len(next(iter(history.values())))+1)
pd.DataFrame(history, index=epochs)
# Out:
#         loss  mrcnn_bbox_loss  mrcnn_class_loss  mrcnn_mask_loss  \
# 1   1.788373         0.524508          0.289887         0.438849
# 2   1.571345         0.441852          0.238730         0.376839
# 3   1.299755         0.369296          0.155612         0.360299
# 4   1.312881         0.352829          0.159685         0.352115
# 5   1.285811         0.352203          0.171719         0.361242
# 6   1.325550         0.349324          0.188430         0.363728
# 7   1.289120         0.352287          0.188666         0.362420
# 8   1.261108         0.340446          0.190373         0.357716
# 9   1.297165         0.347617          0.210738         0.358473
# 10  1.214179         0.335480          0.183943         0.355664
#
#     rpn_bbox_loss  rpn_class_loss  val_loss  val_mrcnn_bbox_loss  \
# 1        0.516366        0.018756  1.858738             0.588031
# 2        0.497970        0.015946  2.392015             0.567264
# 3        0.403935        0.010606  2.050240             0.402321
# 4        0.436749        0.011495  1.974821             0.554799
# 5        0.389155        0.011484  1.761874             0.446411
# 6        0.413451        0.010610  1.567409             0.436390
# 7        0.375202        0.010536  1.993173             0.524899
# 8        0.362141        0.010424  1.705681             0.369757
# 9        0.369189        0.011141  2.042902             0.439547
# 10       0.328193        0.010891  1.525021             0.434951
#
#     val_mrcnn_class_loss  val_mrcnn_mask_loss  val_rpn_bbox_loss  \
# 1               0.433549             0.434485           0.380533
# 2               0.153477             0.511186           1.138866
# 3               0.086334             0.416286           1.135044
# 4               0.256339             0.459969           0.687229
# 5               0.230078             0.451921           0.621455
# 6               0.200157             0.409364           0.508453
# 7               0.209016             0.453498           0.784414
# 8               0.289921             0.349644           0.682334
# 9               0.240526             0.414138           0.932952
# 10              0.203911             0.407700           0.470156
#
#     val_rpn_class_loss
# 1             0.022133
# 2             0.021215
# 3             0.010247
# 4             0.016477
# 5             0.012000
# 6             0.013037
# 7             0.021337
# 8             0.014017
# 9             0.015730
# 10            0.008295

# %%
plt.figure(figsize=(15,5))

plt.subplot(131)
plt.plot(epochs, history["loss"], label="Train loss")
plt.plot(epochs, history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(epochs, history["mrcnn_class_loss"], label="Train class ce")
plt.plot(epochs, history["val_mrcnn_class_loss"], label="Valid class ce")
plt.legend()
plt.subplot(133)
plt.plot(epochs, history["mrcnn_bbox_loss"], label="Train box loss")
plt.plot(epochs, history["val_mrcnn_bbox_loss"], label="Valid box loss")
plt.legend()

plt.show()

# %%
best_epoch = np.argmin(history["val_loss"])
print("Best Epoch:", best_epoch + 1, history["val_loss"][best_epoch])
# Out:
# Best Epoch: 10 1.5250214385986327

# %% [markdown]
# #### 7.4) Inference

# %%
model_path = os.path.join(models_working_DIR,'pneumonia20190305T2032','mask_rcnn_pneumonia_0010.h5')
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=models_save_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/ops/sparse_ops.py:1165: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# Loading weights from  /home/ubuntu/healthcare/pneumonia_lungfish/src/models_working/pneumonia20190305T2032/mask_rcnn_pneumonia_0010.h5
# Re-starting from epoch 10

# %%
#show few example of ground truth vs. predictions on the validation dataset 
dataset = dataset_val
fig = plt.figure(figsize=(10, 30))

for i in range(6):

    image_id = random.choice(dataset.image_ids)
    
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)
    
    #print(original_image.shape)
    plt.subplot(6, 2, 2*i + 1)
    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset.class_names,
                                colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
    
    plt.subplot(6, 2, 2*i + 2)
    results = model.detect([original_image]) #, verbose=1)
    r = results[0]
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset.class_names, r['scores'], 
                                colors=get_colors_for_class_ids(r['class_ids']), ax=fig.axes[-1])
    print(image_id)
# Out:
# *** No instances to display ***
#
# 24
#
# *** No instances to display ***
#
# 3410
#
# *** No instances to display ***
#
# 12474
#
# *** No instances to display ***
#
# 3568
#
# *** No instances to display ***
#
# 32
#
# *** No instances to display ***
#
# 998

# %% [markdown]
# #### 7-ktest) submit to kaggle test

# %%
# Make predictions on test images, write out sample submission
def predict(image_fps, filepath='submission.csv', min_conf=0.95):
    # assume square image
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    #resize_factor = ORIG_SIZE
    with open(filepath, 'w') as file:
        file.write("patientId,PredictionString\n")

        for image_id in (image_fps):
            ds = pydicom.read_file(image_id)
            image = ds.pixel_array
            # If grayscale. Convert to RGB for consistency.
            if len(image.shape) != 3 or image.shape[2] != 3:
                image = np.stack((image,) * 3, -1)
            image, window, scale, padding, crop = utils.resize_image(
                image,
                min_dim=config.IMAGE_MIN_DIM,
                min_scale=config.IMAGE_MIN_SCALE,
                max_dim=config.IMAGE_MAX_DIM,
                mode=config.IMAGE_RESIZE_MODE)

            patient_id = os.path.splitext(os.path.basename(image_id))[0]

            results = model.detect([image])
            r = results[0]

            out_str = ""
            out_str += patient_id
            out_str += ","
            assert( len(r['rois']) == len(r['class_ids']) == len(r['scores']) )
            if len(r['rois']) == 0:
                pass
            else:
                num_instances = len(r['rois'])

                for i in range(num_instances):
                    if r['scores'][i] > min_conf:
                        out_str += ' '
                        out_str += str(round(r['scores'][i], 2))
                        out_str += ' '

                        # x1, y1, width, height
                        x1 = r['rois'][i][1]
                        y1 = r['rois'][i][0]
                        width = r['rois'][i][3] - x1
                        height = r['rois'][i][2] - y1
                        bboxes_str = "{} {} {} {}".format(x1*resize_factor, y1*resize_factor, \
                                                           width*resize_factor, height*resize_factor)
                        out_str += bboxes_str

            file.write(out_str+"\n")

# %%
submission_fp = os.path.join(ktest_data_DIR, 'submission.csv')
test_dicom_dir = '/home/ubuntu/healthcare/pneumonia_lungfish/src/data/test'
test_image_fps = get_dicom(test_dicom_dir)
predict(test_image_fps, filepath=submission_fp)
print(submission_fp)
output = pd.read_csv(submission_fp)
output.head(5)
# Out:
#                               patientId  \
# 0  3135b442-13ea-496f-b5ba-e0e074494c16
# 1  04026d9e-895d-4b87-9d73-3d6fb58e53a3
# 2  c0cdf524-c836-423b-aee6-65afc46567db
# 3  0d0a219a-f091-430b-a0c4-6a90faa1636c
# 4  2e00f7b7-ea1d-4da8-baa1-ffcbcc60be8d
#
#                                     PredictionString
# 0                                                NaN
# 1   0.96 568.0 444.0 204.0 284.0 0.95 180.0 444.0...
# 2                       0.97 648.0 216.0 244.0 400.0
# 3                       0.96 224.0 428.0 148.0 336.0
# 4                                                NaN

# %% [markdown]
# ### Select trained model

# %% [markdown]
# #### Next
# pipeline, early stop, tuning, metrics

# %% [markdown]
# #### Reference
# https://colab.research.google.com/github/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-kaggle.ipynb#scrollTo=8EBVA1M60yAj
#
# https://www.kaggle.com/hmendonca/mask-rcnn-and-coco-transfer-learning-lb-0-155
#
# https://www.kaggle.com/kmader/lung-opacity-overview
#
# https://www.kaggle.com/aantonova/attempt-of-metric-s-implementation

# %% [markdown]
# ## Error
